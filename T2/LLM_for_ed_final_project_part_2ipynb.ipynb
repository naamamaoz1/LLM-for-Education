# %%
pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.37.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from anthropic)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (0.19.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from anthropic) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->anthropic)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->anthropic)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.23.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.0->anthropic) (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.2.3)
# Downloading anthropic-0.37.1-py3-none-any.whl (945 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 946.0/946.0 kB 10.2 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.5 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.0 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 9.9 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, anthropic
# Successfully installed anthropic-0.37.1 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1

# %%
import anthropic
import numpy as np
import pandas as pd
import os
import glob

from IPython.display import display, Latex, HTML
from math import exp

# %%
drive_dirpath = "/content/drive/MyDrive/sadna"

# %%
MODEL = "claude-3-5-sonnet-20240620"
MAX_TOKENS = 1024
API_KEY = ""

# %% [markdown]
# # API Example

# %%
prompt_content = "Hello, Claude"

# %%
client = anthropic.Anthropic(api_key=API_KEY)
response = client.messages.create(model=MODEL,
                                  max_tokens=MAX_TOKENS,
                                  temperature=0.2,
                                  messages=[
                                      {"role": "user", "content": prompt_content}
                                      ]
)

# %%
response
# Out:
# Message(id='msg_014qTqGx2KumxMW5SvWa9C2h', content=[TextBlock(text="Hello! It's nice to meet you. How can I assist you today?", type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=10, output_tokens=19))

# %%
response_text = response.content[0].text
response_text
# Out:
# "Hello! It's nice to meet you. How can I assist you today?"

# %% [markdown]
# # API Function

# %%
def ask_claude_single_prompt(prompt_content, temp=0.2):
    client = anthropic.Anthropic(api_key=API_KEY)
    response = client.messages.create(model=MODEL,
                                    max_tokens=MAX_TOKENS,
                                    temperature=temp,
                                    messages=[
                                        {"role": "user", "content": prompt_content}
                                    ]
    )

    return response.content[0].text

# %%
def conversation_with_claude(prompts, temp=0.2):
    """
    Have a multi-turn conversation with Claude using the Anthropic Messages API.

    Args:
        prompts (list): List of strings containing the prompts to send to Claude
        temp (float, optional): Temperature parameter for response generation. Defaults to 0.2

    Returns:
        list: List of Claude's responses for each prompt
    """
    client = anthropic.Anthropic(api_key=API_KEY)
    messages = []
    responses = []

    for prompt in prompts:
        # Add the user's new message
        messages.append({"role": "user", "content": prompt})

        # Get Claude's response
        response = client.messages.create(
            model=MODEL,
            max_tokens=MAX_TOKENS,
            temperature=temp,
            messages=messages
        )

        # Add Claude's response to the message history
        assistant_message = response.content[0].text
        messages.append({"role": "assistant", "content": assistant_message})
        responses.append(assistant_message)

    return responses

# %% [markdown]
# ### Example use

# %%
ask_claude_single_prompt("Hi my name is Edan")
# Out:
# "Hello Edan! It's nice to meet you. How can I assist you today? Is there anything specific you'd like to know or discuss?"

# %%
conv_example = ["Hi my name is Edan" , "What is my name?"]
conversation_with_claude(conv_example)
# Out:
# ["Hello Edan! It's nice to meet you. How can I assist you today? Is there anything specific you'd like to know or discuss?",
#  'Your name is Edan, as you mentioned in your introduction.']

# %% [markdown]
# # Example Question - Single Prompt

# %%
OPENING = """Here is a question from a computer science Data Structures course.
Solve the question.
Question:\n"""

# %%
example_q = """\textit{In a sequence of \(N\) Insert operations into a 2-3 tree (initially empty), let \(F(N)\) be the number of times a node split is performed in the tree when inserting \(N\) elements, in the worst case. Let \(G(N)\) be the total number of computer operations, when inserting \(N\) elements, in the worst case.}

\textit{What is the tightest upper bound on the ratio \(G(N)/F(N)\)?}

\begin{enumerate}
    \item \(\theta(1)\)
    \item \(\theta(\log(N))\)
    \item \(\theta(N)\)
    \item \(\theta(N \log(N))\)
    \item \(\theta\left(\frac{N}{\log(N)}\right)\)
\end{enumerate}
"""

# %%
example_answer = ask_claude_single_prompt(OPENING + example_q)
print(example_answer)
# Out:
# Let's approach this step-by-step:
#
# 1) First, let's consider F(N), the number of node splits:
#    - In the worst case, a split occurs every time we insert into a full node.
#    - The height of a 2-3 tree with N elements is O(log N).
#    - Each split creates at most one new node per level.
#    - Therefore, F(N) is O(N) in the worst case.
#
# 2) Now, let's consider G(N), the total number of operations:
#    - For each insertion, we need to traverse the tree from root to leaf.
#    - The height of the tree is O(log N).
#    - For each level, we perform a constant number of operations.
#    - Therefore, each insertion takes O(log N) operations.
#    - For N insertions, G(N) is O(N log N) in the worst case.
#
# 3) Now, we need to find the tightest upper bound on G(N)/F(N):
#    G(N)/F(N) = O(N log N) / O(N) = O(log N)
#
# 4) In Big Theta notation, this is θ(log N).
#
# Therefore, the correct answer is option 2: θ(log N).
#
# This makes sense intuitively as well. The total number of operations (G(N)) is larger than the number of splits (F(N)) by a factor of log N, because for each insertion we need to traverse the tree (log N operations) whether a split occurs or not.

# %%
second_prompt = "Write the number of the final answer, without additional text."

# %%
conv_res = conversation_with_claude([OPENING+example_q, second_prompt])

# %%
for a in conv_res:
  print(a , "\n\n\n\n\n")
# Out:
# Let's approach this step-by-step:
#
# 1) First, let's consider F(N), the number of node splits:
#    - In the worst case, a split occurs every time we insert into a full node.
#    - The number of splits is proportional to the number of insertions.
#    - Therefore, F(N) = Θ(N)
#
# 2) Now, let's consider G(N), the total number of operations:
#    - For each insertion, we need to traverse the tree to find the correct position.
#    - The height of a 2-3 tree is logarithmic in the number of elements.
#    - Each insertion takes Θ(log N) operations.
#    - There are N insertions.
#    - Therefore, G(N) = Θ(N log N)
#
# 3) Now, we need to find the ratio G(N) / F(N):
#    G(N) / F(N) = Θ(N log N) / Θ(N) = Θ(log N)
#
# 4) Among the given options, Θ(log N) is present.
#
# Therefore, the tightest upper bound on the ratio G(N)/F(N) is Θ(log N).
#
# The correct answer is option 2: Θ(log N).
#
#
#
#
#
# 2

# %% [markdown]
# # Run analysis

# %% [markdown]
# ### Create DF for results

# %%
cols = ["question_id",
    "model",
    "model_version",
    "question_prompt",
    "prompt_engineering_method",
    "timestamp",
    "answers_vector",
    "probabilities_vector",
    "tight_accuracy",
    "loose_accuracy"
]

df = pd.DataFrame(columns=cols)
filepath = os.path.join(drive_dirpath, "dataframe.tsv")
df.to_csv(filepath, sep="\t")

# %%
questions_df = pd.read_excel(os.path.join(drive_dirpath, "combined_dataframes.xlsx"))

# %% [markdown]
# ## Process Questions

# %%
GENERAL_FILENAME = "{model}-{model_version}_{question_id}_na_rep{rep_num}.txt"
COT_FILENAME = "{model}-{model_version}_{question_id}_cot_rep{rep_num}.txt"

FIRST_PROMPT = """Here is a multiple-choice/true-false question from the Data Structures course. Solve the question."""
SECOND_PROMPT = "Write the final answer as a number, without additional text."
COT_SUFFIX = "Solve it step by step."

# %% [markdown]
# ### Process Types C-D

# %%
def process_questions(df, model, model_version, num_reps):
  rows = []

  for idx in range(len(df)):
    year = df.loc[idx, "exam_year"]
    semester = df.loc[idx, "semester"]
    moed = df.loc[idx, "moed"]
    q_num = df.loc[idx , "question_number"]

    question_id = f"{year}{semester}{moed}_q{q_num}"
    question_text = df.loc[idx , "question_translation_latex"]
    dataset = df.loc[idx , "dataset"]
    has_sol = df.loc[idx , "has_solution"]
    q_type = df.loc[idx , "question_type"].upper()
    multiple_choice_answer = df.loc[idx, "multiple_choice_answer"]

    if dataset == "tested" and has_sol == True and q_type != "B":
      for rep in range(1, num_reps+1):
        row = {
            "question_id": question_id,
            "question_type": q_type,
            "multiple_choice_answer": multiple_choice_answer,
            "model": model,
            "model_version": model_version,
            "question_prompt": f"{FIRST_PROMPT}\nQuestion: {question_text}",
            "prompt_engineering_method": None,
            "rep_num": rep,
            "result_filename": GENERAL_FILENAME.format(model=model, model_version=model_version, question_id=question_id, rep_num=rep),
            "timestamp": None,
            "answers_vector": None,
            "probabilities_vector": None,
            "tight_accuracy": None,
            "loose_accuracy": None,
          }
        rows.append(row)

      for rep in range(1, num_reps+1):
        row = {
            "question_id": question_id,
            "question_type": q_type,
            "multiple_choice_answer": multiple_choice_answer,
            "model": model,
            "model_version": model_version,
            "question_prompt": f"{FIRST_PROMPT}\n{COT_SUFFIX}\nQuestion: {question_text}",
            "prompt_engineering_method": "COT",
            "rep_num": rep,
            "result_filename": COT_FILENAME.format(model=model, model_version=model_version, question_id=question_id, rep_num=rep),
            "timestamp": None,
            "answers_vector": None,
            "probabilities_vector": None,
            "tight_accuracy": None,
            "loose_accuracy": None
          }
        rows.append(row)

  df = pd.DataFrame(rows)
  return df

# %%
q_df = process_questions(questions_df, "claude", MODEL, 5)

# %%
q_df.to_excel(os.path.join(drive_dirpath, "empty_dataframe.xlsx"))

# %% [markdown]
# ### Process Type B

# %%
FIRST_PROMPT = """Here is a question from the Data Structures course. Solve the question."""
SECOND_PROMPT = "Write the final answer, without additional text."
COT_SUFFIX = "Solve it step by step."

# %%
def process_questions_type_b(df, model, model_version, num_reps):
  rows = []

  for idx in range(len(df)):
    year = df.loc[idx, "exam_year"]
    semester = df.loc[idx, "semester"]
    moed = df.loc[idx, "moed"]
    q_num = df.loc[idx , "question_number"]

    question_id = f"{year}{semester}{moed}_q{q_num}"
    question_text = df.loc[idx , "question_translation_latex"]
    dataset = df.loc[idx , "dataset"]
    has_sol = df.loc[idx , "has_solution"]
    q_type = df.loc[idx , "question_type"].upper()
    multiple_choice_answer = df.loc[idx, "multiple_choice_answer"]

    if dataset == "tested" and has_sol == True and q_type == "B":
      for rep in range(1, num_reps+1):
        row = {
            "question_id": question_id,
            "question_type": q_type,
            "multiple_choice_answer": multiple_choice_answer,
            "model": model,
            "model_version": model_version,
            "question_prompt": f"{FIRST_PROMPT}\nQuestion: {question_text}",
            "prompt_engineering_method": None,
            "rep_num": rep,
            "result_filename": GENERAL_FILENAME.format(model=model, model_version=model_version, question_id=question_id, rep_num=rep),
            "timestamp": None,
            "answers_vector": None,
            "probabilities_vector": None,
            "tight_accuracy": None,
            "loose_accuracy": None,
          }
        rows.append(row)

      for rep in range(1, num_reps+1):
        row = {
            "question_id": question_id,
            "question_type": q_type,
            "multiple_choice_answer": multiple_choice_answer,
            "model": model,
            "model_version": model_version,
            "question_prompt": f"{FIRST_PROMPT}\n{COT_SUFFIX}\nQuestion: {question_text}",
            "prompt_engineering_method": "COT",
            "rep_num": rep,
            "result_filename": COT_FILENAME.format(model=model, model_version=model_version, question_id=question_id, rep_num=rep),
            "timestamp": None,
            "answers_vector": None,
            "probabilities_vector": None,
            "tight_accuracy": None,
            "loose_accuracy": None
          }
        rows.append(row)

  df = pd.DataFrame(rows)
  return df

# %%
q_df_type_b = process_questions_type_b(questions_df, "claude", MODEL, 5)

# %%
q_df_type_b.to_excel(os.path.join(drive_dirpath, "empty_dataframe_type_b.xlsx"))

# %% [markdown]
# ## Run Analysis: Type C-D Questions

# %%
from pathlib import Path

# %%
def run_analysis(df, directory, start=0):
  df_res = df.copy(deep=True)

  directory = Path(directory)
  directory.mkdir(exist_ok=True)

  try:
    for idx in range(start, len(df)):
      print(f"Processing {idx} - {df_res.loc[idx, 'question_id']}...")

      prompt = df_res.loc[idx, "question_prompt"]
      prompt_engineering = df_res.loc[idx , "prompt_engineering_method"]

      first_message = prompt
      second_message = SECOND_PROMPT

      # Ask model and get timestamp
      messages = [first_message , second_message]
      full_answer , final_answer = conversation_with_claude(messages)
      timestamp = str(pd.Timestamp.now())

      df_res.loc[idx, "timestamp"] = timestamp

      # Write full answer
      filename = df_res.loc[idx , "result_filename"]
      filepath = os.path.join(directory, filename)
      with open(filepath, "w", encoding="utf-8") as file:
        file.write(full_answer)

      # Write short answer
      df_res.loc[idx, "chat_response"] = final_answer

      if idx % 10 == 0:
        df_res.to_excel(os.path.join(drive_dirpath, "results.xlsx"))

  except Exception as e:
    print(e)
  finally:
    df_res.to_excel(os.path.join(drive_dirpath, "results.xlsx"))
    return df_res

# %%
analysis_results_df = run_analysis(q_df, os.path.join(drive_dirpath, "responses"))
# Out:
# Processing 0 - 2002aa_q2...
# Processing 1 - 2002aa_q2...
# Processing 2 - 2002aa_q2...
# Processing 3 - 2002aa_q2...
# Processing 4 - 2002aa_q2...
# Processing 5 - 2002aa_q2...
# Processing 6 - 2002aa_q2...
# Processing 7 - 2002aa_q2...
# Processing 8 - 2002aa_q2...
# Processing 9 - 2002aa_q2...
# Processing 10 - 2002aa_q3...
# Processing 11 - 2002aa_q3...
# Processing 12 - 2002aa_q3...
# Processing 99 - 2004aa_q3...
# Processing 100 - 2004aa_q5...
# Processing 101 - 2004aa_q5...
# Processing 102 - 2004aa_q5...
# Processing 103 - 2004aa_q5...
# Processing 104 - 2004aa_q5...
# Processing 105 - 2004aa_q5...
# Processing 106 - 2004aa_q5...
# Processing 107 - 2004aa_q5...
# Processing 108 - 2004aa_q5...
# Processing 109 - 2004aa_q5...
# Processing 110 - 2004aa_q6...
# Processing 111 - 2004aa_q6...
# Processing 112 - 2004aa_q6...
# Processing 113 - 2004aa_q6...
# Processing 114 - 2004aa_q6...
# Processing 115 - 2004aa_q6...
# Processing 116 - 2004aa_q6...
# Processing 117 - 2004aa_q6...
# Processing 118 - 2004aa_q6...
# Processing 119 - 2004aa_q6...
# Processing 120 - 2004aa_q8...
# Processing 121 - 2004aa_q8...
# Processing 122 - 2004aa_q8...
# Processing 123 - 2004aa_q8...
# Processing 124 - 2004aa_q8...
# Processing 125 - 2004aa_q8...
# Processing 126 - 2004aa_q8...
# Processing 127 - 2004aa_q8...
# Processing 128 - 2004aa_q8...
# Processing 129 - 2004aa_q8...
# Processing 130 - 2004ba,b_q1...
# Processing 131 - 2004ba,b_q1...
# Processing 132 - 2004ba,b_q1...
# Processing 133 - 2004ba,b_q1...
# Processing 134 - 2004ba,b_q1...
# Processing 135 - 2004ba,b_q1...
# Processing 136 - 2004ba,b_q1...
# Processing 137 - 2004ba,b_q1...
# Processing 138 - 2004ba,b_q1...
# Processing 139 - 2004ba,b_q1...
# Processing 140 - 2004ba,b_q2...
# Processing 141 - 2004ba,b_q2...
# Processing 142 - 2004ba,b_q2...
# Processing 143 - 2004ba,b_q2...
# Processing 144 - 2004ba,b_q2...
# Processing 145 - 2004ba,b_q2...
# Processing 146 - 2004ba,b_q2...
# Processing 147 - 2004ba,b_q2...
# Processing 148 - 2004ba,b_q2...
# Processing 149 - 2004ba,b_q2...
# Processing 150 - 2004ba,b_q5...
# Processing 151 - 2004ba,b_q5...
# Processing 152 - 2004ba,b_q5...
# Processing 153 - 2004ba,b_q5...
# Processing 154 - 2004ba,b_q5...
# Processing 155 - 2004ba,b_q5...
# Processing 156 - 2004ba,b_q5...
# Processing 157 - 2004ba,b_q5...
# Processing 158 - 2004ba,b_q5...
# Processing 159 - 2004ba,b_q5...
# Processing 160 - 2004ba,b_q6...
# Processing 161 - 2004ba,b_q6...
# Processing 162 - 2004ba,b_q6...
# Processing 163 - 2004ba,b_q6...
# Processing 164 - 2004ba,b_q6...
# Processing 165 - 2004ba,b_q6...
# Processing 166 - 2004ba,b_q6...
# Processing 167 - 2004ba,b_q6...
# Processing 168 - 2004ba,b_q6...
# Processing 169 - 2004ba,b_q6...
# Processing 170 - 2004ba,b_q7...
# Processing 171 - 2004ba,b_q7...
# Processing 172 - 2004ba,b_q7...
# Processing 173 - 2004ba,b_q7...
# Processing 174 - 2004ba,b_q7...
# Processing 175 - 2004ba,b_q7...
# Processing 176 - 2004ba,b_q7...
# Processing 177 - 2004ba,b_q7...
# Processing 178 - 2004ba,b_q7...
# Processing 770 - 2016ab_q7...
# Processing 771 - 2016ab_q7...
# Processing 772 - 2016ab_q7...
# Processing 773 - 2016ab_q7...
# Processing 774 - 2016ab_q7...
# Processing 775 - 2016ab_q7...
# Processing 776 - 2016ab_q7...
# Processing 777 - 2016ab_q7...
# Processing 778 - 2016ab_q7...
# Processing 779 - 2016ab_q7...
# Processing 780 - 2016ab_q9...
# Processing 781 - 2016ab_q9...
# Processing 782 - 2016ab_q9...
# Processing 783 - 2016ab_q9...
# Processing 784 - 2016ab_q9...
# Processing 785 - 2016ab_q9...
# Processing 786 - 2016ab_q9...
# Processing 787 - 2016ab_q9...
# Processing 788 - 2016ab_q9...
# Processing 789 - 2016ab_q9...
# Processing 790 - 2013BB_q1...
# Processing 791 - 2013BB_q1...
# Processing 792 - 2013BB_q1...
# Processing 793 - 2013BB_q1...
# Processing 794 - 2013BB_q1...
# Processing 795 - 2013BB_q1...
# Processing 796 - 2013BB_q1...
# Processing 797 - 2013BB_q1...
# Processing 798 - 2013BB_q1...
# Processing 799 - 2013BB_q1...
# Processing 800 - 2013BB_q2...
# Processing 801 - 2013BB_q2...
# Processing 802 - 2013BB_q2...
# Processing 803 - 2013BB_q2...
# Processing 804 - 2013BB_q2...
# Processing 805 - 2013BB_q2...
# Processing 806 - 2013BB_q2...
# Processing 807 - 2013BB_q2...
# Processing 808 - 2013BB_q2...
# Processing 809 - 2013BB_q2...
# Processing 810 - 2013BB_q3...
# Processing 811 - 2013BB_q3...
# Processing 812 - 2013BB_q3...
# Processing 813 - 2013BB_q3...
# Processing 814 - 2013BB_q3...
# Processing 815 - 2013BB_q3...
# Processing 816 - 2013BB_q3...
# Processing 817 - 2013BB_q3...
# Processing 818 - 2013BB_q3...
# Processing 819 - 2013BB_q3...
# Processing 820 - 2013BB_q4...
# Processing 821 - 2013BB_q4...
# Processing 822 - 2013BB_q4...
# Processing 823 - 2013BB_q4...
# Processing 824 - 2013BB_q4...
# Processing 825 - 2013BB_q4...
# Processing 826 - 2013BB_q4...
# Processing 827 - 2013BB_q4...
# Processing 828 - 2013BB_q4...
# Processing 829 - 2013BB_q4...
# Processing 830 - 2013BB_q5...
# Processing 831 - 2013BB_q5...
# Processing 832 - 2013BB_q5...
# Processing 833 - 2013BB_q5...
# Processing 834 - 2013BB_q5...
# Processing 835 - 2013BB_q5...
# Processing 836 - 2013BB_q5...
# Processing 837 - 2013BB_q5...
# Processing 838 - 2013BB_q5...
# Processing 839 - 2013BB_q5...
# Processing 840 - 2013BB_q8...
# Processing 841 - 2013BB_q8...
# Processing 842 - 2013BB_q8...
# Processing 843 - 2013BB_q8...
# Processing 844 - 2013BB_q8...
# Processing 845 - 2013BB_q8...
# Processing 846 - 2013BB_q8...
# Processing 847 - 2013BB_q8...
# Processing 848 - 2013BB_q8...
# Processing 849 - 2013BB_q8...
# Processing 850 - 2013BB_q10...
# Processing 851 - 2013BB_q10...
# Processing 852 - 2013BB_q10...
# Processing 853 - 2013BB_q10...
# Processing 854 - 2013BB_q10...
# Processing 855 - 2013BB_q10...
# Processing 856 - 2013BB_q10...
# Processing 857 - 2013BB_q10...
# Processing 858 - 2013BB_q10...
# Processing 859 - 2013BB_q10...
# Processing 860 - 2013BB_q11...
# Processing 861 - 2013BB_q11...
# Processing 862 - 2013BB_q11...
# Processing 863 - 2013BB_q11...
# Processing 864 - 2013BB_q11...
# Processing 865 - 2013BB_q11...
# Processing 866 - 2013BB_q11...
# Processing 867 - 2013BB_q11...
# Processing 868 - 2013BB_q11...
# Processing 869 - 2013BB_q11...
# Processing 870 - 2013BB_q12...
# Processing 871 - 2013BB_q12...
# Processing 872 - 2013BB_q12...
# Processing 873 - 2013BB_q12...
# Processing 874 - 2013BB_q12...
# Processing 875 - 2013BB_q12...
# Processing 876 - 2013BB_q12...
# Processing 877 - 2013BB_q12...
# Processing 878 - 2013BB_q12...
# Processing 879 - 2013BB_q12...
# Processing 880 - 2013BB_q13...
# Processing 881 - 2013BB_q13...
# Processing 882 - 2013BB_q13...
# Processing 883 - 2013BB_q13...
# Processing 884 - 2013BB_q13...
# Processing 885 - 2013BB_q13...
# Processing 886 - 2013BB_q13...
# Processing 887 - 2013BB_q13...
# Processing 888 - 2013BB_q13...
# Processing 889 - 2013BB_q13...
# Processing 890 - 2013BB_q14...
# Processing 891 - 2013BB_q14...
# Processing 892 - 2013BB_q14...
# Processing 893 - 2013BB_q14...
# Processing 894 - 2013BB_q14...
# Processing 895 - 2013BB_q14...
# Processing 896 - 2013BB_q14...
# Processing 897 - 2013BB_q14...
# Processing 898 - 2013BB_q14...
# Processing 899 - 2013BB_q14...
# Processing 900 - 2013BB_q16...
# Processing 901 - 2013BB_q16...
# Processing 902 - 2013BB_q16...
# Processing 903 - 2013BB_q16...
# Processing 904 - 2013BB_q16...
# Processing 905 - 2013BB_q16...
# Processing 906 - 2013BB_q16...
# Processing 907 - 2013BB_q16...
# Processing 908 - 2013BB_q16...
# Processing 909 - 2013BB_q16...
# Processing 910 - 2013BB_q17...
# Processing 911 - 2013BB_q17...
# Processing 912 - 2013BB_q17...
# Processing 913 - 2013BB_q17...
# Processing 914 - 2013BB_q17...
# Processing 915 - 2013BB_q17...
# Processing 916 - 2013BB_q17...
# Processing 917 - 2013BB_q17...
# Processing 918 - 2013BB_q17...
# Processing 919 - 2013BB_q17...
# Processing 920 - 2013BB_q19...
# Processing 921 - 2013BB_q19...
# Processing 922 - 2013BB_q19...
# Processing 923 - 2013BB_q19...
# Processing 924 - 2013BB_q19...
# Processing 925 - 2013BB_q19...
# Processing 926 - 2013BB_q19...
# Processing 927 - 2013BB_q19...
# Processing 928 - 2013BB_q19...
# Processing 929 - 2013BB_q19...
# Processing 930 - 2013BB_q20...
# Processing 931 - 2013BB_q20...
# Processing 932 - 2013BB_q20...
# Processing 933 - 2013BB_q20...
# Processing 934 - 2013BB_q20...
# Processing 935 - 2013BB_q20...
# Processing 936 - 2013BB_q20...
# Processing 937 - 2013BB_q20...
# Processing 938 - 2013BB_q20...
# Processing 939 - 2013BB_q20...
# Processing 940 - 2013BB_q21...
# Processing 1589 - 2018AA_q14-b...
# Processing 1590 - 2018AA_q14-e...
# Processing 1591 - 2018AA_q14-e...
# Processing 1592 - 2018AA_q14-e...
# Processing 1593 - 2018AA_q14-e...
# Processing 1594 - 2018AA_q14-e...
# Processing 1595 - 2018AA_q14-e...
# Processing 1596 - 2018AA_q14-e...
# Processing 1597 - 2018AA_q14-e...
# Processing 1598 - 2018AA_q14-e...
# Processing 1599 - 2018AA_q14-e...

# %%
analysis_results_df
# Out:
#        question_id question_type multiple_choice_answer   model  \
# 0        2002aa_q2             D                      2  claude
# 1        2002aa_q2             D                      2  claude
# 2        2002aa_q2             D                      2  claude
# 3        2002aa_q2             D                      2  claude
# 4        2002aa_q2             D                      2  claude
# ...            ...           ...                    ...     ...
# 1595  2018AA_q14-e             C                  False  claude
# 1596  2018AA_q14-e             C                  False  claude
# 1597  2018AA_q14-e             C                  False  claude
# 1598  2018AA_q14-e             C                  False  claude
# 1599  2018AA_q14-e             C                  False  claude
#
#                    model_version  \
# 0     claude-3-5-sonnet-20240620
# 1     claude-3-5-sonnet-20240620
# 2     claude-3-5-sonnet-20240620
# 3     claude-3-5-sonnet-20240620
# 4     claude-3-5-sonnet-20240620
# ...                          ...
# 1595  claude-3-5-sonnet-20240620
# 1596  claude-3-5-sonnet-20240620
# 1597  claude-3-5-sonnet-20240620
# 1598  claude-3-5-sonnet-20240620
# 1599  claude-3-5-sonnet-20240620
#
#                                         question_prompt  \
# 0     Here is a multiple-choice/true-false question ...
# 1     Here is a multiple-choice/true-false question ...
# 2     Here is a multiple-choice/true-false question ...
# 3     Here is a multiple-choice/true-false question ...
# 4     Here is a multiple-choice/true-false question ...
# ...                                                 ...
# 1595  Here is a multiple-choice/true-false question ...
# 1596  Here is a multiple-choice/true-false question ...
# 1597  Here is a multiple-choice/true-false question ...
# 1598  Here is a multiple-choice/true-false question ...
# 1599  Here is a multiple-choice/true-false question ...
#
#      prompt_engineering_method  rep_num  \
# 0                         None        1
# 1                         None        2
# 2                         None        3
# 3                         None        4
# 4                         None        5
# ...                        ...      ...
# 1595                       COT        1
# 1596                       COT        2
# 1597                       COT        3
# 1598                       COT        4
# 1599                       COT        5
#
#                                         result_filename  \
# 0     claude-claude-3-5-sonnet-20240620_2002aa_q2_na...
# 1     claude-claude-3-5-sonnet-20240620_2002aa_q2_na...
# 2     claude-claude-3-5-sonnet-20240620_2002aa_q2_na...
# 3     claude-claude-3-5-sonnet-20240620_2002aa_q2_na...
# 4     claude-claude-3-5-sonnet-20240620_2002aa_q2_na...
# ...                                                 ...
# 1595  claude-claude-3-5-sonnet-20240620_2018AA_q14-e...
# 1596  claude-claude-3-5-sonnet-20240620_2018AA_q14-e...
# 1597  claude-claude-3-5-sonnet-20240620_2018AA_q14-e...
# 1598  claude-claude-3-5-sonnet-20240620_2018AA_q14-e...
# 1599  claude-claude-3-5-sonnet-20240620_2018AA_q14-e...
#
#                        timestamp answers_vector probabilities_vector  \
# 0     2024-10-27 15:02:03.202705           None                 None
# 1     2024-10-27 15:02:10.355556           None                 None
# 2     2024-10-27 15:02:17.235528           None                 None
# 3     2024-10-27 15:02:24.143092           None                 None
# 4     2024-10-27 15:02:31.528756           None                 None
# ...                          ...            ...                  ...
# 1595  2024-10-27 18:37:56.669139           None                 None
# 1596  2024-10-27 18:38:07.341619           None                 None
# 1597  2024-10-27 18:38:17.009818           None                 None
# 1598  2024-10-27 18:38:27.143647           None                 None
# 1599  2024-10-27 18:38:38.180145           None                 None
#
#      tight_accuracy loose_accuracy chat_response
# 0              None           None             2
# 1              None           None             2
# 2              None           None             2
# 3              None           None             3
# 4              None           None             3
# ...             ...            ...           ...
# 1595           None           None             1
# 1596           None           None             1
# 1597           None           None             1
# 1598           None           None             1
# 1599           None           None             1
#
# [1600 rows x 15 columns]

# %% [markdown]
# ## Run Analysis: Type B Questions

# %%
def run_analysis_type_b(df, directory, start=0):
  df_res = df.copy(deep=True)

  directory = Path(directory)
  directory.mkdir(exist_ok=True)

  try:
    for idx in range(start, len(df)):
      print(f"Processing {idx} - {df_res.loc[idx, 'question_id']}...")

      prompt = df_res.loc[idx, "question_prompt"]
      prompt_engineering = df_res.loc[idx , "prompt_engineering_method"]

      first_message = prompt
      second_message = SECOND_PROMPT

      # Ask model and get timestamp
      messages = [first_message , second_message]
      full_answer , final_answer = conversation_with_claude(messages)
      timestamp = str(pd.Timestamp.now())

      df_res.loc[idx, "timestamp"] = timestamp

      # Write full answer
      filename = df_res.loc[idx , "result_filename"]
      filepath = os.path.join(directory, filename)
      with open(filepath, "w", encoding="utf-8") as file:
        file.write(full_answer)

      # Write short answer
      df_res.loc[idx, "chat_response"] = final_answer

      if idx % 10 == 0:
        df_res.to_excel(os.path.join(drive_dirpath, "results_type_b.xlsx"))

  except Exception as e:
    print(e)
  finally:
    df_res.to_excel(os.path.join(drive_dirpath, "results_type_b.xlsx"))
    return df_res

# %%
res_type_b = run_analysis_type_b(q_df_type_b, os.path.join(drive_dirpath, "responses_type_b"))
# Out:
# Processing 0 - 2009ba_q12-a...
# Processing 1 - 2009ba_q12-a...
# Processing 2 - 2009ba_q12-a...
# Processing 3 - 2009ba_q12-a...
# Processing 4 - 2009ba_q12-a...
# Processing 5 - 2009ba_q12-a...
# Processing 6 - 2009ba_q12-a...
# Processing 7 - 2009ba_q12-a...
# Processing 8 - 2009ba_q12-a...
# Processing 9 - 2009ba_q12-a...
# Processing 10 - 2010ba_q2-d...
# Processing 11 - 2010ba_q2-d...
# Processing 12 - 2010ba_q2-d...
# Processing 13 - 2010ba_q2-d...
# Processing 14 - 2010ba_q2-d...
# Processing 15 - 2010ba_q2-d...
# Processing 16 - 2010ba_q2-d...
# Processing 17 - 2010ba_q2-d...
# Processing 18 - 2010ba_q2-d...
# Processing 19 - 2010ba_q2-d...
# Processing 20 - 2010ba_q3-a...
# Processing 21 - 2010ba_q3-a...
# Processing 22 - 2010ba_q3-a...
# Processing 23 - 2010ba_q3-a...
# Processing 24 - 2010ba_q3-a...
# Processing 25 - 2010ba_q3-a...
# Processing 26 - 2010ba_q3-a...
# Processing 181 - 2018AB_q1-a...
# Processing 182 - 2018AB_q1-a...
# Processing 183 - 2018AB_q1-a...
# Processing 184 - 2018AB_q1-a...
# Processing 185 - 2018AB_q1-a...
# Processing 186 - 2018AB_q1-a...
# Processing 187 - 2018AB_q1-a...
# Processing 188 - 2018AB_q1-a...
# Processing 189 - 2018AB_q1-a...
# Processing 190 - 2018AB_q1-d...
# Processing 191 - 2018AB_q1-d...
# Processing 192 - 2018AB_q1-d...
# Processing 193 - 2018AB_q1-d...
# Processing 194 - 2018AB_q1-d...
# Processing 195 - 2018AB_q1-d...
# Processing 196 - 2018AB_q1-d...
# Processing 197 - 2018AB_q1-d...
# Processing 198 - 2018AB_q1-d...
# Processing 199 - 2018AB_q1-d...
# Processing 200 - 2018AB_q1-e...
# Processing 201 - 2018AB_q1-e...
# Processing 202 - 2018AB_q1-e...
# Processing 203 - 2018AB_q1-e...
# Processing 204 - 2018AB_q1-e...
# Processing 205 - 2018AB_q1-e...
# Processing 206 - 2018AB_q1-e...
# Processing 207 - 2018AB_q1-e...
# Processing 208 - 2018AB_q1-e...
# Processing 209 - 2018AB_q1-e...
# Processing 210 - 2018AB_q2-a...
# Processing 211 - 2018AB_q2-a...
# Processing 212 - 2018AB_q2-a...
# Processing 213 - 2018AB_q2-a...
# Processing 214 - 2018AB_q2-a...
# Processing 215 - 2018AB_q2-a...
# Processing 216 - 2018AB_q2-a...
# Processing 217 - 2018AB_q2-a...
# Processing 218 - 2018AB_q2-a...
# Processing 219 - 2018AB_q2-a...
# Processing 220 - 2018AB_q2-b...
# Processing 221 - 2018AB_q2-b...
# Processing 222 - 2018AB_q2-b...
# Processing 223 - 2018AB_q2-b...
# Processing 224 - 2018AB_q2-b...
# Processing 225 - 2018AB_q2-b...
# Processing 226 - 2018AB_q2-b...
# Processing 227 - 2018AB_q2-b...
# Processing 228 - 2018AB_q2-b...
# Processing 229 - 2018AB_q2-b...
# Processing 230 - 2018AB_q3...
# Processing 231 - 2018AB_q3...
# Processing 232 - 2018AB_q3...
# Processing 233 - 2018AB_q3...
# Processing 234 - 2018AB_q3...
# Processing 235 - 2018AB_q3...
# Processing 236 - 2018AB_q3...
# Processing 237 - 2018AB_q3...
# Processing 238 - 2018AB_q3...
# Processing 239 - 2018AB_q3...
# Processing 240 - 2018AB_q4-a...
# Processing 241 - 2018AB_q4-a...
# Processing 242 - 2018AB_q4-a...
# Processing 243 - 2018AB_q4-a...
# Processing 244 - 2018AB_q4-a...
# Processing 245 - 2018AB_q4-a...
# Processing 246 - 2018AB_q4-a...
# Processing 247 - 2018AB_q4-a...
# Processing 248 - 2018AB_q4-a...
# Processing 249 - 2018AB_q4-a...
# Processing 250 - 2018AB_q4-c...
# Processing 251 - 2018AB_q4-c...
# Processing 252 - 2018AB_q4-c...
# Processing 253 - 2018AB_q4-c...
# Processing 254 - 2018AB_q4-c...
# Processing 255 - 2018AB_q4-c...
# Processing 256 - 2018AB_q4-c...
# Processing 257 - 2018AB_q4-c...
# Processing 258 - 2018AB_q4-c...
# Processing 259 - 2018AB_q4-c...
# Processing 260 - 2018AB_q5...
# Processing 261 - 2018AB_q5...
# Processing 262 - 2018AB_q5...
# Processing 263 - 2018AB_q5...
# Processing 264 - 2018AB_q5...
# Processing 265 - 2018AB_q5...
# Processing 266 - 2018AB_q5...
# Processing 267 - 2018AB_q5...
# Processing 268 - 2018AB_q5...
# Processing 269 - 2018AB_q5...
# Processing 270 - 2018AB_q6-a...
# Processing 271 - 2018AB_q6-a...
# Processing 272 - 2018AB_q6-a...
# Processing 273 - 2018AB_q6-a...
# Processing 274 - 2018AB_q6-a...
# Processing 275 - 2018AB_q6-a...
# Processing 276 - 2018AB_q6-a...
# Processing 277 - 2018AB_q6-a...
# Processing 278 - 2018AB_q6-a...
# Processing 279 - 2018AB_q6-a...
# Processing 280 - 2018AB_q7-a...
# Processing 281 - 2018AB_q7-a...
# Processing 282 - 2018AB_q7-a...
# Processing 283 - 2018AB_q7-a...
# Processing 284 - 2018AB_q7-a...
# Processing 285 - 2018AB_q7-a...
# Processing 286 - 2018AB_q7-a...
# Processing 287 - 2018AB_q7-a...
# Processing 288 - 2018AB_q7-a...
# Processing 289 - 2018AB_q7-a...
# Processing 290 - 2018AB_q7-b...
# Processing 291 - 2018AB_q7-b...
# Processing 292 - 2018AB_q7-b...
# Processing 293 - 2018AB_q7-b...
# Processing 294 - 2018AB_q7-b...
# Processing 295 - 2018AB_q7-b...
# Processing 296 - 2018AB_q7-b...
# Processing 297 - 2018AB_q7-b...
# Processing 298 - 2018AB_q7-b...
# Processing 299 - 2018AB_q7-b...
# Processing 300 - 2018AB_q8-a...
# Processing 301 - 2018AB_q8-a...
# Processing 302 - 2018AB_q8-a...
# Processing 303 - 2018AB_q8-a...
# Processing 304 - 2018AB_q8-a...
# Processing 305 - 2018AB_q8-a...
# Processing 306 - 2018AB_q8-a...
# Processing 307 - 2018AB_q8-a...
# Processing 308 - 2018AB_q8-a...
# Processing 309 - 2018AB_q8-a...
# Processing 310 - 2018AB_q8-c...
# Processing 311 - 2018AB_q8-c...
# Processing 312 - 2018AB_q8-c...
# Processing 313 - 2018AB_q8-c...
# Processing 314 - 2018AB_q8-c...
# Processing 315 - 2018AB_q8-c...
# Processing 316 - 2018AB_q8-c...
# Processing 317 - 2018AB_q8-c...
# Processing 318 - 2018AB_q8-c...
# Processing 319 - 2018AB_q8-c...
# Processing 320 - 2018AB_q9-c...
# Processing 321 - 2018AB_q9-c...
# Processing 322 - 2018AB_q9-c...
# Processing 323 - 2018AB_q9-c...
# Processing 324 - 2018AB_q9-c...
# Processing 325 - 2018AB_q9-c...
# Processing 326 - 2018AB_q9-c...
# Processing 327 - 2018AB_q9-c...
# Processing 328 - 2018AB_q9-c...
# Processing 329 - 2018AB_q9-c...
# Processing 330 - 2018AB_q10...
# Processing 331 - 2018AB_q10...
# Processing 332 - 2018AB_q10...
# Processing 333 - 2018AB_q10...
# Processing 334 - 2018AB_q10...
# Processing 335 - 2018AB_q10...
# Processing 336 - 2018AB_q10...
# Processing 337 - 2018AB_q10...
# Processing 338 - 2018AB_q10...
# Processing 339 - 2018AB_q10...
# Processing 340 - 2018AA_q15-b...
# Processing 341 - 2018AA_q15-b...
# Processing 342 - 2018AA_q15-b...
# Processing 343 - 2018AA_q15-b...
# Processing 344 - 2018AA_q15-b...
# Processing 345 - 2018AA_q15-b...
# Processing 346 - 2018AA_q15-b...
# Processing 347 - 2018AA_q15-b...
# Processing 348 - 2018AA_q15-b...
# Processing 349 - 2018AA_q15-b...
# Processing 350 - 2018AA_q15-c...
# Processing 351 - 2018AA_q15-c...
# Processing 352 - 2018AA_q15-c...
# Processing 353 - 2018AA_q15-c...
# Processing 354 - 2018AA_q15-c...
# Processing 355 - 2018AA_q15-c...
# Processing 356 - 2018AA_q15-c...
# Processing 357 - 2018AA_q15-c...
# Processing 358 - 2018AA_q15-c...
# Processing 359 - 2018AA_q15-c...
# Processing 360 - 2018AA_q16-a...
# Processing 361 - 2018AA_q16-a...
# Processing 362 - 2018AA_q16-a...
# Processing 363 - 2018AA_q16-a...
# Processing 364 - 2018AA_q16-a...
# Processing 365 - 2018AA_q16-a...
# Processing 366 - 2018AA_q16-a...
# Processing 367 - 2018AA_q16-a...
# Processing 368 - 2018AA_q16-a...
# Processing 369 - 2018AA_q16-a...
# Processing 370 - 2018AA_q16-b...
# Processing 371 - 2018AA_q16-b...
# Processing 372 - 2018AA_q16-b...
# Processing 373 - 2018AA_q16-b...
# Processing 374 - 2018AA_q16-b...
# Processing 375 - 2018AA_q16-b...
# Processing 376 - 2018AA_q16-b...
# Processing 377 - 2018AA_q16-b...
# Processing 378 - 2018AA_q16-b...
# Processing 379 - 2018AA_q16-b...
# Processing 380 - 2018AA_q16-c...
# Processing 381 - 2018AA_q16-c...
# Processing 382 - 2018AA_q16-c...
# Processing 383 - 2018AA_q16-c...
# Processing 384 - 2018AA_q16-c...
# Processing 385 - 2018AA_q16-c...
# Processing 386 - 2018AA_q16-c...
# Processing 387 - 2018AA_q16-c...
# Processing 388 - 2018AA_q16-c...
# Processing 389 - 2018AA_q16-c...
# Processing 390 - 2017AB_q1-c...
# Processing 391 - 2017AB_q1-c...
# Processing 392 - 2017AB_q1-c...
# Processing 393 - 2017AB_q1-c...
# Processing 394 - 2017AB_q1-c...
# Processing 395 - 2017AB_q1-c...
# Processing 396 - 2017AB_q1-c...
# Processing 397 - 2017AB_q1-c...
# Processing 398 - 2017AB_q1-c...
# Processing 399 - 2017AB_q1-c...

# %%
res_type_b
# Out:
#       question_id question_type multiple_choice_answer   model  \
# 0    2009ba_q12-a             B                     na  claude
# 1    2009ba_q12-a             B                     na  claude
# 2    2009ba_q12-a             B                     na  claude
# 3    2009ba_q12-a             B                     na  claude
# 4    2009ba_q12-a             B                     na  claude
# ..            ...           ...                    ...     ...
# 395   2017AB_q1-c             B                     na  claude
# 396   2017AB_q1-c             B                     na  claude
# 397   2017AB_q1-c             B                     na  claude
# 398   2017AB_q1-c             B                     na  claude
# 399   2017AB_q1-c             B                     na  claude
#
#                   model_version  \
# 0    claude-3-5-sonnet-20240620
# 1    claude-3-5-sonnet-20240620
# 2    claude-3-5-sonnet-20240620
# 3    claude-3-5-sonnet-20240620
# 4    claude-3-5-sonnet-20240620
# ..                          ...
# 395  claude-3-5-sonnet-20240620
# 396  claude-3-5-sonnet-20240620
# 397  claude-3-5-sonnet-20240620
# 398  claude-3-5-sonnet-20240620
# 399  claude-3-5-sonnet-20240620
#
#                                        question_prompt  \
# 0    Here is a question from the Data Structures co...
# 1    Here is a question from the Data Structures co...
# 2    Here is a question from the Data Structures co...
# 3    Here is a question from the Data Structures co...
# 4    Here is a question from the Data Structures co...
# ..                                                 ...
# 395  Here is a question from the Data Structures co...
# 396  Here is a question from the Data Structures co...
# 397  Here is a question from the Data Structures co...
# 398  Here is a question from the Data Structures co...
# 399  Here is a question from the Data Structures co...
#
#     prompt_engineering_method  rep_num  \
# 0                        None        1
# 1                        None        2
# 2                        None        3
# 3                        None        4
# 4                        None        5
# ..                        ...      ...
# 395                       COT        1
# 396                       COT        2
# 397                       COT        3
# 398                       COT        4
# 399                       COT        5
#
#                                        result_filename  \
# 0    claude-claude-3-5-sonnet-20240620_2009ba_q12-a...
# 1    claude-claude-3-5-sonnet-20240620_2009ba_q12-a...
# 2    claude-claude-3-5-sonnet-20240620_2009ba_q12-a...
# 3    claude-claude-3-5-sonnet-20240620_2009ba_q12-a...
# 4    claude-claude-3-5-sonnet-20240620_2009ba_q12-a...
# ..                                                 ...
# 395  claude-claude-3-5-sonnet-20240620_2017AB_q1-c_...
# 396  claude-claude-3-5-sonnet-20240620_2017AB_q1-c_...
# 397  claude-claude-3-5-sonnet-20240620_2017AB_q1-c_...
# 398  claude-claude-3-5-sonnet-20240620_2017AB_q1-c_...
# 399  claude-claude-3-5-sonnet-20240620_2017AB_q1-c_...
#
#                       timestamp answers_vector probabilities_vector  \
# 0    2024-10-30 13:38:18.886077           None                 None
# 1    2024-10-30 13:38:26.564253           None                 None
# 2    2024-10-30 13:38:35.364287           None                 None
# 3    2024-10-30 13:38:42.707298           None                 None
# 4    2024-10-30 13:38:50.206875           None                 None
# ..                          ...            ...                  ...
# 395  2024-10-30 14:41:16.320627           None                 None
# 396  2024-10-30 14:41:26.486325           None                 None
# 397  2024-10-30 14:41:35.808736           None                 None
# 398  2024-10-30 14:41:45.623503           None                 None
# 399  2024-10-30 14:41:56.810345           None                 None
#
#     tight_accuracy loose_accuracy  \
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ..             ...            ...
# 395           None           None
# 396           None           None
# 397           None           None
# 398           None           None
# 399           None           None
#
#                                          chat_response
# 0                                           (n-1)(n)/2
# 1                                             n(n-1)/2
# 2                                         (n² - n) / 2
# 3                                             n(n-1)/2
# 4                                             n(n-1)/2
# ..                                                 ...
# 395  Two AVL trees of size n each cannot be merged ...
# 396  It is not possible to merge two AVL trees of s...
# 397  It is not possible to merge two AVL trees of s...
# 398  Disproved. It is not possible to merge two AVL...
# 399  No, two AVL trees of size n each cannot be mer...
#
# [400 rows x 15 columns]
